# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanLG1998/InmersionDatosALURA/blob/main/INMERSION_DATOS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Inmersión de Datos**
#
# ---
#
# > Organizador: ALURA
#
# > Autor de este proyecto: López García Juan Ángel
#
#
# ---

# %% [markdown]
# # **Aula 1**

# %%
# Conexión del notebook con Google Drive
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Importando biblioteca de python para la manipulación y análisis de datos
import pandas as pd

# Creando dataset con la información a utilizar (inmuebles a la venta en Bogotá) 
inmuebles = pd.read_csv('/content/drive/MyDrive/InmersionDatosALURA/inmuebles_bogota.csv') 

# Mostrando la información del dataset (primeras cinco columnas)
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %%
# Consultando la forma nuestro dataset (num. filas, num. columnas)
inmuebles.shape
# Out:
# (9520, 8)

# %%
# Consultando los atributos del data set
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
# Renombrando las columnas cuyos nombres tienen caracteres especiales
columnas = {'Baños':'Banos','Área':'Area'} # Diccionario de datos key:value
inmuebles = inmuebles.rename(columns=columnas)

# Visualizando una muestra de 10 elementos de nuestro dataset
inmuebles.sample(11)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 1763  Apartamento             Apartamento en venta en Usaquén             2
# 9325  Apartamento      Apartamento en venta en Nueva Zelandia             3
# 5735  Apartamento             Apartamento en venta en Usaquén             3
# 200   Apartamento         Apartamento en venta en El Contador             3
# 5296  Apartamento                Apartamento en venta en Bosa             3
# 3325  Apartamento      Apartamento en venta en Quinta Paredes             3
# 8822  Apartamento  Apartamento en venta en Zona Noroccidental             1
# 7656  Apartamento             Apartamento en venta en Kennedy             3
# 5165  Apartamento      Apartamento en venta en Chapinero Alto             1
# 8169         Casa                       Casa en venta en Suba             2
# 1074  Apartamento             Apartamento en venta en Usaquén             4
#
#       Banos  Area              Barrio  \
# ...

# %%
# Obteniendo información sobre nuestro dataset
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
# Consultando información para un índice específico del dataset 
inmuebles.iloc[225]
# Out:
# Tipo                                    Casa
# Descripcion     Casa en venta en El Contador
# Habitaciones                               4
# Banos                                      3
# Area                                     210
# Barrio                           El Contador
# UPZ                               Los Cedros
# Valor                          $ 900.000.000
# Name: 225, dtype: object

# %%
# Consultando información para un rango específico  
# Nota: la información del valor superior del rango no se muestra
inmuebles.iloc[300:305]
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %%
# Consultando la información de un índice esoecifico para un atributo en especial
inmuebles['Valor'][300]
# Out:
# '$ 116.100.000'

# %%
# Consultando la información para un atributo en especial en un rango específico
inmuebles['Valor'][300:305]

# Averiguando el tipo de dato de la estructura creada
type(inmuebles['Valor'][300:305]) # Ya no es un dataframe ahora es una serie
# Out:
# pandas.core.series.Series

# %%
# Obteniendo la media de la columna o atributo "Area"
inmuebles.Area.mean()

# El área promedio de los inmuebles es...
# Out:
# 146.66470588235293

# %%
# Mostrado una muestra de 100 datos del dataset para explorar y ubicar características que puedan resultar interesantes
inmuebles.sample(100)
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 8501  Apartamento        Apartamento en venta en Chapinero             1
# 3671  Apartamento      Apartamento en venta en Andes Norte             3
# 395          Casa     Casa en venta en Nicolas De Federman            12
# 4600  Apartamento         Apartamento en venta en El Batán             3
# 7598         Casa                 Casa en venta en Kennedy             5
# ...           ...                                      ...           ...
# 834   Apartamento     Apartamento en venta en Puente Largo             3
# 6840         Casa                Casa en venta en Cedritos             5
# 8519  Apartamento         Apartamento en venta en Fontibón             2
# 8316         Casa           Casa en venta en Villa Alsacia             3
# 5942  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area               Barrio                                 UPZ  \
# ...

# %%
# Comparando si los inmuebles se encuentran en el barrio de "Chico Reservado"
(inmuebles.Barrio == 'Chico Reservado')
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
# Obteniendo la cantidad de inmuebles que que encuentran en el barrio de "Chico Reservado"
sum((inmuebles.Barrio == 'Chico Reservado'))
# Out:
# 225

# %%
# Consultando el tipo de dato de la estructura creada
inmuebles_chico = (inmuebles.Barrio == 'Chico Reservado')
type(inmuebles_chico) # Es un panda series
# Out:
# pandas.core.series.Series

# %%
# Creando nuevo dataset con los inmuebles ubicados en Chico Reservado
chico_reservado = inmuebles[inmuebles_chico] # Se filtra el dataset original
chico_reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# ...

# %%
# Calculando el área promedio de los inmuebles en Chico Reservado
chico_reservado.Area.mean()
# Out:
# 142.78666666666666

# %%
# Calculando el área promedio de todos los inmuebles a la venta en Bogotá
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %% [markdown]
# **Conclusión** : *Se concluye que los inmuebles de Chico Reservado son ligeramente más pequeños que el resto de Bogotá*

# %%
# Calculando cuantos barrios hay en nuestro dataset original
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %%
# Visualizando el conteo de inmuebles por barrio
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
# Calculando cuantos UPZ hay en nuestro dataset original
len(inmuebles.UPZ.value_counts())
# Out:
# 63

# %%
# Creando un gráfico con el conteo de inmuebles por barrio 
inmuebles_barrio = inmuebles.Barrio.value_counts()
inmuebles_barrio.plot.bar()
# Out:
# <Axes: >

# %%
# Creando un gráfico con el top 10 de barrios con mayor cantidad de inmuebles a la venta
inmuebles_barrio.head(10).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# **Conclusión** : *Como conclusión, la mayor cantidad de inmuebles a la venta en Bogotá se encuentran en la zona norte*

# %% [markdown]
# **Desafío**
#
#
# 1. Promedio de área de todos los inmuebles en los barrios en el dataset. El top 10.
#
# 2. Consultar otros datos estadísticos, conteo, mediana, valores mínimo y máximo.

# %%
# Agrupando inmuebles por barrio y obteniendo el área promedio
#   Se ordenan para graficar de forma descendente
area_inmuebles = inmuebles.groupby(['Barrio']).Area.mean().sort_values(ascending=False)

# Graficando el TOP 10 de Barrios cuyos inmuebles tienen el mayor área en promedio
area_inmuebles.head(10).plot.bar(title='Área promedio de los inmuebles en venta (Bogotá)', xlabel='Barrio', ylabel='Área [m^2]');

# %% [markdown]
# **Identificación de problematica** : *De acuerdo con el gráfico anterior, se observa que el barrio de Modelia posee inmuebles con un área promedio mayor a 4 mil metros cuadrados. Situación que aterridaza a la realidad es sin lugar a dudas muy rara, pues se aleja demasiado del promedio de todos los demás barrios.*
#
# **Solución Plantada** : *Procederé a realizar un análisis a detalle de los inmuebles del barrio de Modelia para verificar que los inmuebles son en efecto, muy grandes, o por el contrario, hay una minoría de inmuebles gigantescos que están alterando al estadístico y causando un comportamiento anormal.*

# %%
# Filtrando el dataset original para aislar los inmuebles de Modelia
modelia = inmuebles.loc[inmuebles.loc[:, 'Barrio'] == 'Modelia']
# Ordenando el dataset de forma descendente según el área
modelia_sorted = modelia.sort_values(by=['Area'], ascending=False)
# Mostrando los primeros diez registros del dataset ordenado
modelia_sorted.head(10)
# Out:
#       Tipo               Descripcion  Habitaciones  Banos    Area   Barrio  \
# 7073  Casa  Casa en venta en Modelia             4      3  166243  Modelia
# 8562  Casa  Casa en venta en Modelia             5      4     400  Modelia
# 4913  Casa  Casa en venta en Modelia             5      4     320  Modelia
# 2147  Casa  Casa en venta en Modelia             5      4     320  Modelia
# 4914  Casa  Casa en venta en Modelia             5      4     320  Modelia
# 5059  Casa  Casa en venta en Modelia             7      6     287  Modelia
# 7908  Casa  Casa en venta en Modelia             3      3     275  Modelia
# 9326  Casa  Casa en venta en Modelia             5      3     270  Modelia
# 2257  Casa  Casa en venta en Modelia             5      4     244  Modelia
# 1283  Casa  Casa en venta en Modelia             8      4     236  Modelia
#
#            UPZ            Valor
# 7073  Fontibón    $ 850.000.000
# 8562  Fontibón    $ 950.000.000
# 4913  Fontibón    $ 750.000.000
# ...

# %%
# Obteniendo valor máximo de área en los inmuebles de Modelia
modelia['Area'].max()
# Out:
# 166243

# %%
# Obteniendo valor mínimo de área en los inmuebles de Modelia
modelia['Area'].min()
# Out:
# 48

# %%
# Obteniendo mediana de área en los inmuebles de Modelia
modelia['Area'].median()
# Out:
# 155.5

# %%
# Obteniendo moda de área en los inmuebles de Modelia
mode_modelia = modelia['Area'].value_counts().sort_values(ascending=False)
mode_modelia.head()
# Out:
# 320    3
# 108    3
# 181    3
# 78     3
# 70     2
# Name: Area, dtype: int64

# %% [markdown]
# **Identifiación del registro que causa problemas** : *De acuerdo con el dataset generado y los cálculos realizados... el registro 7073 de nuestro dataset original, el cual corresponde a un inmueble en venta en el barrio Modelia cuya área es de 166243 metros cuadrados es justamente el registro que está causando el comportamiento anormal del estadistico media y por lo tanto debería ser ignorado durante el calculo, consiguiendo así una valor más realista del tamaño promedio de los inmuebles de Modelia.*

# %%
# Creando nuevo dataset sin el registro que causa anomalías (reg. 7073)
inmuebles_clean = inmuebles.drop([7073])

# Agrupando inmuebles por barrio y obteniendo el área promedio
#   Se ordenan para graficar de forma descendente
n_area_inmuebles = inmuebles_clean.groupby(['Barrio']).Area.mean().sort_values(ascending=False)

# Graficando el TOP 10 de Barrios cuyos inmuebles tienen el mayor área en promedio
n_area_inmuebles.head(10).plot.bar(title='Área promedio de los inmuebles en venta (Bogotá)', xlabel='Barrio', ylabel='Área [m^2]');

# %% [markdown]
# **Conclusión Final** : *El resultado final que se observa en el último gráfico generado se adecúa de mejor manera a la realidad del tamaño de los inmuebles. Siendo Libertador el barrio con los inmuebles más grandes*

# %% [markdown]
# # **Aula 2**

# %%
# Revisando una muestra del dataset para comprender su estructura
inmuebles.sample(5)
# Out:
#              Tipo                           Descripcion  Habitaciones  Banos  \
# 1564  Apartamento  Apartamento en venta en San Patricio             2      2
# 925   Apartamento       Apartamento en venta en Kennedy             3      2
# 6375  Apartamento  Apartamento en venta en Santa Teresa             1      1
# 3799         Casa   Casa en venta en Zona Noroccidental             3      4
# 2858  Apartamento          Apartamento en venta en Bosa             3      1
#
#       Area              Barrio                                    UPZ  \
# 1564    63        San Patricio  USAQUÉN: Country Club + Santa Bárbara
# 925     54             Kennedy                        Kennedy Central
# 6375    50        Santa Teresa                    San Cristóbal Norte
# 3799   333  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 2858    48                Bosa                           Bosa Central
#
#                 Valor
# 1564    $ 346.990.000
# 925     $ 237.000.000
# ...

# %%
# Obteniendo información del dataset
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
# Se trabajará con el valor de los inmuebles
#   así que consultamos su tipo de dato
type(inmuebles.Valor[0])
# Out:
# str

# %%
# Como el atributo "valor" es de tipo String si intentamos sumar los valores los concatenará 
inmuebles.Valor[0]+inmuebles.Valor[1]+inmuebles.Valor[:5]
# Out:
# 0      $ 360.000.000$ 670.000.000$ 360.000.000
# 1      $ 360.000.000$ 670.000.000$ 670.000.000
# 2    $ 360.000.000$ 670.000.000$ 1.120.000.000
# 3      $ 360.000.000$ 670.000.000$ 890.000.000
# 4      $ 360.000.000$ 670.000.000$ 970.000.000
# Name: Valor, dtype: object

# %%
# Como es String puedo aplicar tratamiento de String, como la siguiente función que separa la cadena de texto
#   Ahora ya tenemos el signo de pesos separado del valor númerico
inmuebles.Valor[0].split()
# Out:
# ['$', '360.000.000']

# %%
# Separando todos lo valores del atributo "valor" dentro del dataset
valor = inmuebles.Valor.str.split(expand=True) # El parámetro de Split() índica que el resultado será un DataFrame y no un PandaSeries
inmuebles['Moneda'] = valor[0] # Asignamos nombre a la colummna que contiene los signos de pesos
inmuebles['Precio'] = valor[1] # Asignamos nombre a la columna que contiene el valor númerico
inmuebles.sample(3)
# Out:
#              Tipo                             Descripcion  Habitaciones  \
# 2359  Apartamento  Apartamento en venta en Barrios Unidos             3
# 3974  Apartamento         Apartamento en venta en Usaquén             2
# 5897  Apartamento    Apartamento en venta en San Patricio             3
#
#       Banos  Area          Barrio                                    UPZ  \
# 2359      2    56  Barrios Unidos                              Los Andes
# 3974      2    60         Usaquén                                Usaquén
# 5897      3   114    San Patricio  USAQUÉN: Country Club + Santa Bárbara
#
#               Valor Moneda       Precio
# 2359  $ 145.000.000      $  145.000.000
# 3974  $ 422.000.000      $  422.000.000
# 5897  $ 785.000.000      $  785.000.000

# %%
# Consultamos nuevamente la información del dataset
inmuebles.info()

# Se observa que el atributo "Precio" sigue siendo de tipo Objeto o String
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %%
# Antes de realiar la conversión a un objeto númerico es necesario realizar un tratamiento previo
#   En este caso se eliminan los puntos de los precios para que no cause problemas en el futuro
#     y se generen confusiones con las separaciones de millares y el punto decimal
inmuebles['Precio'] = inmuebles['Precio'].str.replace('.','',regex=True)

# %%
# Consultando el dataset para observar los cambios
inmuebles[['Precio','Barrio']] # El doble corchete es para indicar que el resultado sea un dataframe
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %%
# Hasta este momento el atibuto "Valor" sigue siendo objeto
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %%
# Se crea una nueva columna en el dataset que corresponde al precio en millones de los inmuebles
#   Además se realiza la conversión a tipo flotante para trabajar con valores númericos
inmuebles['Precio_Millon'] = inmuebles.Precio.astype('float')/1000000

# Al consultar la información es posible notar las características de la nueva colummna que hemos creado
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Banos          9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %%
# Al utilizar describe se crean los estadísticos de los atributos o culumnas con valores númericos
inmuebles.describe()
# Out:
#        Habitaciones        Banos           Area  Precio_Millon
# count   9520.000000  9520.000000    9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706     602.062354
# std        2.049856     1.255314    1731.379622     704.602062
# min        1.000000     0.000000       2.000000      60.000000
# 25%        2.000000     2.000000      57.000000     250.000000
# 50%        3.000000     2.000000      80.000000     409.182500
# 75%        3.000000     3.000000     135.000000     680.000000
# max      110.000000     9.000000  166243.000000   16000.000000

# %%
# Se modifican los parametros de pandas para que la precisión de decimales sea de dos
#   y sólo muestre dos valores decimales
pd.set_option('display.precision',2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
inmuebles.describe()

# count -> cantidad de registros
# mean -> media
# std -> desviación estandar
# min -> valor mínimo en los registros
# max -> valor máximo en los registros
# Out:
#        Habitaciones   Banos      Area  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %% [markdown]
# *Se aprecia que hay un inmueble con 110 habitaciones, situación que resulta muy extraña es por ello que se procede a localizar dicho registro*

# %%
# Localizando el inmueble con 110 habitaciones
inmuebles.loc[inmuebles.Habitaciones == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %% [markdown]
# *Todo apunta aque fue un error humano de registro de los datos, ya que el número de habitaciones es igual al área.*

# %% [markdown]
# *Por otro lado, también se aprecia que existe un inmueble con un área de 2 m2*

# %%
# Loacalizando el inmueble con área de 2 m2
inmuebles.loc[inmuebles.Area == 2]
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8401  Apartamento  Apartamento en venta en San Cristobal             3      1
#
#       Area         Barrio      UPZ          Valor Moneda     Precio  \
# 8401     2  San Cristobal  Sosiego  $ 180.000.000      $  180000000
#
#       Precio_Millon
# 8401         180.00

# %% [markdown]
# *De igual manera todo apunta que fue un error de captura de datos.*

# %%
# Generando un histograma con los precios de los inmuebles
#   se utiliza para saber la distribución de frecuencia de una variable, en este caso el precio
inmuebles['Precio_Millon'].plot.hist(bins=10) # Mientras más bins más rangos de números y más barras se generan

# En este caso, el histograma no sirve de mucho
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Mejorando el gráfico con ayuda de matplotlib y seaborn

# Importando las bibliotecas
import matplotlib.pyplot as plt 
import seaborn as sns

# Preparando el lienzo o espacio que vamos a utilizar para nuestro gráfico
plt.figure(figsize=(10,6)) # Tamaño de la figura (ancho,altura)

# Creando el histograma con los datos que queremos
grafica = sns.histplot(data=inmuebles, x='Precio_Millon', kde=True, hue='Tipo') # Se activa la curva de densidad y la dimensión tipo
grafica.set_title('Distribución de Valores de los inmuebles en Bogotá') # Asignando título al gráfico
plt.xlim((50,1000)) # Definiendo límites (min,max)
plt.savefig('/content/drive/MyDrive/InmersionDatosALURA/valor_inmuebles.png',format='png') # Guardando el gráfico
plt.show() # Desplegando el gráfico

# %% [markdown]
# **Desafíos**
#
# 1. Estudiar mejor el histograma de valores, seleccionar 3 tipos de inmuebles (Refinar el gráfico: Títulos, aumentar el tamaño de labels, colores, conclusión de la información)
#
# 2. Precio del m2 por barrio y hacer el gráfico más adecuado para esta nueva variable.

# %%
# Desafío 1
plt.figure(figsize=(12,8))
grafica = sns.histplot(data=inmuebles, x='Precio_Millon', kde=True, hue='Tipo', hue_order=['Apartamento','Casa','Lote'], palette='husl', multiple="dodge")
grafica.set_title('Distribución de precios de los inmuebles en Bogotá', fontsize=18)
grafica.set_xlabel('Precio [Millones COP]', fontsize=14)
grafica.set_ylabel('Num. Inmuebles', fontsize=14)
plt.xlim((50,2000))
plt.ylim((0,800))
plt.savefig('/content/drive/MyDrive/InmersionDatosALURA/desafio1.png',format='png')
plt.show() # Desplegando el gráfico

# %%
plt.figure(figsize=(12,8))
grafica = sns.histplot(data=inmuebles, x='Precio_Millon', kde=True, hue='Tipo', hue_order=['Apartamento','Casa','Lote'], palette='husl', multiple="dodge")
grafica.set_title('Distribución de precios de los inmuebles en Bogotá', fontsize=18)
grafica.set_xlabel('Precio [Millones COP]', fontsize=14)
grafica.set_ylabel('Num. Inmuebles', fontsize=14)
plt.xlim((50,2000))
plt.ylim((0,10))
plt.show() # Desplegando el gráfico

# %% [markdown]
# **Conclusiones**
#
# * *De acuerdo con el histograma realizado la oferta de departamentos es muchisimo mayor que cualquier otro tipo de inmueble.*
#
# * *Sin embargo, conforme los precios de los inmuebles van aumentando, la oferta de departamentos respecto a la oferta de casas se iguala.*
#
# * *Por otro lado, decidí mostrar la oferta de Lotes para construcción, pensando en la edificación de una vivienda a futuro. Para mi sorpresa, la oferta es bajísima y los pocos inmuebles de este tipo que se ofertan se encuentran se encuentran por debajo de los 1250 millones de COP.*

# %%
# Desafío 2

plt.figure(figsize=(12,8))

# Calculando el precio por metro cuadrado para cada inmueble
inmuebles['Precio_m2'] = inmuebles['Precio_Millon']/inmuebles['Area']
# Calculando el precio promedio para cada barrio
precio_x_m2 = inmuebles.groupby('Barrio')['Precio_m2'].mean().reset_index().sort_values(by='Precio_m2',ascending=False).head(10)
# Creando el gráfico
grafica = sns.barplot(data=precio_x_m2, x='Precio_m2', y='Barrio', palette='rocket')
grafica.set_title('TOP 10 barrios más caros en Bogotá (Inmuebles en venta)', fontsize=18)
grafica.set_xlabel('Precio por m2 [Millones COP]', fontsize=14)
grafica.set_ylabel('Barrio', fontsize=14)
plt.savefig('/content/drive/MyDrive/InmersionDatosALURA/desafio2_1.png',format='png') # Guardandoe en drive
plt.show() # Desplegando el gráfico

# %%
plt.figure(figsize=(12,8))

# Calculando el precio promedio para cada barrio
precio_x_m2 = inmuebles.groupby('Barrio')['Precio_m2'].mean().reset_index().sort_values(by='Precio_m2',ascending=False).tail(10)
# Creando el gráfico
grafica = sns.barplot(data=precio_x_m2, x='Precio_m2', y='Barrio', palette='crest')
grafica.set_title('TOP 10 barrios más baratos en Bogotá (Inmuebles en venta)', fontsize=18)
grafica.set_xlabel('Precio por m2 [Millones COP]', fontsize=14)
grafica.set_ylabel('Barrio', fontsize=14)
plt.savefig('/content/drive/MyDrive/InmersionDatosALURA/desafio2_2.png',format='png') # Guardando en drive
plt.show() # Desplegando el gráfico

# %% [markdown]
# **Conclusiones**
#
# * *Gracias los dos gráficos generados es posible concluir que el barrio más caro es El Virrey ubicado en la zona norte de Bogotá, pues sus inmuebles en venta tienen en promedio un costo de 10 millones de Pesos Colombianos por metro cuadrado.*
#
# * *Por otro lado, el barrio más barato es Bosa Piamonte ubicado en la zona occidental de Bogotá, con inmuebles en venta con un costo promedio de 1.2 millones de Pesos Colombianos por metro cuadrado.*
#
# * *Finalmente, si se analiza la ubicación de los barrios mostrados en ambos gráficos, es posible notar que los barrios más caros se ubican en la zona norte de Bogotá.*

# %% [markdown]
# # **Aula 3**

# %% [markdown]
# **Explorando formas de obtener el precio por metro cuadrado por barrio**

# %%
# Se borra la colummna generada en el desafío del Aula 2 para evitar confusiones
inmuebles.drop(columns=['Precio_m2'], inplace=True)

# %% [markdown]
# * Opción 1

# %%
 # Calculando el precio del m2 por barrio pero teniendo en cuenta sólo el precio y área del propio inmueble y no los de todo el barrio
inmuebles['Valor_m2_Millon'] = inmuebles['Precio_Millon']/inmuebles['Area'] 
inmuebles.head(3)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
#
#    Banos  Area              Barrio                                 UPZ  \
# 0      2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla         KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#              Valor Moneda      Precio  Precio_Millon  Valor_m2_Millon
# 0    $ 360.000.000      $   360000000         360.00             5.14
# 1    $ 670.000.000      $   670000000         670.00             3.94
# 2  $ 1.120.000.000      $  1120000000        1120.00             7.78

# %%
# Agrupando por barrio y obteniendo el promedio para todas las columnas númericas
#   En este caso se ha obtenido el promedio de medias para todo el barrio
#   En la columna valor_m2_millon se aprecia el precio por m2 de cada barrio
inmuebles.groupby('Barrio').mean()
# Out:
#                     Habitaciones  Banos   Area  Precio_Millon  Valor_m2_Millon
# Barrio
# Alameda                     3.00   2.00  97.00         580.00             5.98
# Alhambra                    3.00   2.94 190.41         752.35             4.33
# Andes Norte                 3.00   2.86 124.86         709.57             6.05
# Antonio Nariño              4.31   2.50 163.06         459.22             3.53
# Barrancas                   2.87   2.13  70.20         314.13             4.42
# ...                          ...    ...    ...            ...              ...
# Villa Maria                 4.69   3.69 207.15         402.85             2.04
# Villas De Granada           3.45   2.32  86.59         282.30             3.17
# Villemar                    2.94   2.06  76.89         303.83             3.99
# Zona Franca                 2.00   1.00  54.00         160.00             2.96
# Zona Noroccidental          3.17   2.51 135.79         620.81             4.62
#
# ...

# %% [markdown]
# * Opción 2

# %%
# Agrupamos por barrio y sumamos los valores
datos_barrio = inmuebles.groupby('Barrio').sum()
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     Valor_m2_Millon
# Barrio
# Alameda                        5.98
# Alhambra                      73.56
# Andes Norte                   42.35
# Antonio Nariño               169.47
# ...

# %%
# Calculando el precio del m2 por barrio pero teniendo en cuenta la suma total de precios y área de todo el barrio
#   En la columna valor_m2_barrio se aprecia el precio por m2 de cada barrio
datos_barrio['Valor_m2_Barrio'] = datos_barrio['Precio_Millon']/datos_barrio['Area']
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     Valor_m2_Millon  Valor_m2_Barrio
# Barrio
# Alameda                        5.98             5.98
# Alhambra                      73.56             3.95
# ...

# %% [markdown]
# **Conclusion:** *Es recomendable obtener el precio por m2 de cada barrio sumando primero el área total del barrio y el precio de los inmuebles, para posteriormente obtener el precio por m2.*

# %%
# Creando un diccionario con el precio por m2 de cada barrio
#   {key:value} = {barrio:precio}
m2_barrio = dict(datos_barrio['Valor_m2_Barrio'])
m2_barrio
# Out:
# {'Alameda': 5.979381443298969,
#  'Alhambra': 3.95118937287612,
#  'Andes Norte': 5.683066361556064,
#  'Antonio Nariño': 2.816232272901495,
#  'Barrancas': 4.4748338081671415,
#  'Barrios Unidos': 2.9599171141243064,
#  'Bella Suiza': 6.2905507012394,
#  'Bellavista Occidental': 2.522711390635919,
#  'Bochica': 3.4078212290502794,
#  'Bogotá D.C': 5.212760277629472,
#  'Bosa': 2.6778451358697213,
#  'Bosa Piamonte': 1.175,
#  'Bosa Porvenir': 3.1666666666666665,
#  'Bosque De Pinos': 6.046475195822455,
#  'Bosque Popular': 3.864097363083164,
#  'Boyaca ': 2.637421499815294,
#  'Buenos Aires': 2.6,
#  'Candelaria La Nueva': 4.0625,
#  'Cantagallo': 5.71920581655481,
#  'Capellania': 4.316791690709752,
#  'Casablanca': 6.245421245421245,
#  'Castilla': 3.4035893155258763,
#  'Cedritos': 5.027419586695463,
#  'Cerros De Suba': 6.202830188679245,
#  'Chapinero': 4.58018576602501,
#  'Chapinero Alto': 6.4239336492891,
#  'Chapinero Central': 6.360286919831224,
# ...

# %%
# Mapeando los precios por m2 de cada barrio a cada inmueble en el dataset original
inmuebles['Valor_m2_Barrio'] = inmuebles['Barrio']
inmuebles['Valor_m2_Barrio'] = inmuebles['Valor_m2_Barrio'].map(m2_barrio)
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio  Precio_Millon  Valor_m2_Millon  \
# ...

# %% [markdown]
# *Se observan las variaciones de precio por m2 en las dos últimas columnas.*

# %%
# Creando el top 10 de barrios con más inmuebles a la venta
top_barrios = inmuebles['Barrio'].value_counts()[:10].index
top_barrios
# Out:
# Index(['Usaquén', 'Zona Noroccidental', 'Bosa', 'Kennedy', 'Cedritos',
#        'Barrios Unidos', 'Engativa', 'Suba', 'Santa Barbara', 'Chapinero'],
#       dtype='object')

# %%
# Retomando nuestro PandasSeries y reseteando el índice para que Barrio deje de ser índice y se convierta en una columna 
datos_barrio.reset_index(inplace=True)
datos_barrio
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 0               Alameda             3      2      97         580.00
# 1              Alhambra            51     50    3237       12790.00
# 2           Andes Norte            21     20     874        4967.00
# 3        Antonio Nariño           207    120    7827       22042.65
# 4             Barrancas            43     32    1053        4712.00
# ..                  ...           ...    ...     ...            ...
# 144         Villa Maria            61     48    2693        5237.00
# 145   Villas De Granada            76     51    1905        6210.62
# 146            Villemar            53     37    1384        5469.00
# 147         Zona Franca             2      1      54         160.00
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valor_m2_Millon  Valor_m2_Barrio
# 0               5.98             5.98
# 1              73.56             3.95
# ...

# %%
# Consultando el top 10 de barrios 
datos_barrio.query('Barrio in @top_barrios') # query('column in @variableReferencia')
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 5        Barrios Unidos          1525   1196   87799      259877.76
# 10                 Bosa          1743    789   34879       93400.56
# 22             Cedritos          1458   1348   53711      270027.73
# 24            Chapinero           892    913   81248      372130.93
# 50             Engativa          1676   1077   59808      172711.73
# 63              Kennedy          2151   1233   61475      207963.65
# 125       Santa Barbara          1073   1162   54693      320097.80
# 132                Suba          1497   1202   61615      266406.04
# 138             Usaquén          3109   3044  148121      837710.36
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valor_m2_Millon  Valor_m2_Barrio
# 5            2070.61             2.96
# 10           1654.36             2.68
# 22           2853.23             5.03
# 24           2466.03             4.58
# ...

# %%
# Creando un gráfico para visualizar los datos de nuestro nuevo dataframe
plt.figure(figsize=(10,8))
# Se compara el barrio y el precio x m2 del top 10 barrios con mayor cantidad de inmuebles a la venta
ax = sns.barplot(x="Barrio", y="Valor_m2_Barrio", data = datos_barrio.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45)

# %%
# Creando un boxplot para visualizar la distribución de los precios por m2 de los inmuebles según su barrio
#   - Las líneas extremas muestran justamente los valores extremos del precio
#   - La línea inicial de la caja índica el 25%, la segunda índica el 50% o mediana y la tercera el 75%
#   - Los puntos fuera del diagrama se consideran outlier o valores atípicos fuera del comportamiento "normal" de los demás valores
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Valor_m2_Millon", data = inmuebles.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %% [markdown]
# **Ejemplo de lectura** : *Para el barrio de Usaquén... el 25% de los inmuebles a la venta tienen un precio por m2 menor a aprox. 4.8 millones de COP; el 50% de los inmuebles tienen un precio menor a 5.1 millones y el 75% de los inmuebles tienen un precio menor a 5.3 millones.*

# %%
# Agregando una condición para mejorar el gráfico y eliminar los outliers
#   Colocando límite al valor por m2
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Valor_m2_Millon", data = inmuebles.query('Barrio in @top_barrios & Valor_m2_Millon < 15'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
# Boxplot con la distribución del área de los inmuebles por barrio
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Area", data = inmuebles.query('Barrio in @top_barrios & Area < 500'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
# Boxplot con la distribución del precio de los inmuebles por barrio
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Precio_Millon", data = inmuebles.query('Barrio in @top_barrios & Precio_Millon < 2000'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %% [markdown]
# **Trabajando con una nueva base de datos**

# %% [markdown]
# Vamos a traer datos estadísticos de la ciudad de Bogotá, directamente del DANE (Departamento Administrativo Nacional de Estadística) y vamos a ver como estos datos nos ayudarían en inclusión de nuevas variables para el cálculo del precio de los inmuebles en la ciudad de Bogotá.
#
# > Encuesta Multiproposito de Bogotá creada por el DANE para obtener información socio-económica y de entorno urbano de los habitantes de Bogotá para la formulación, seguimiento y evaluación de las políticas distritales.
#
# * https://microdatos.dane.gov.co/index.php/catalog/743

# %%
# Creando dataset con los datos descargados de la web sobre el capitulo de identificación
#   Notar que el archivo tiene una decodificación diferente a UTF-8 
#   Se identifica el separador para mostrar los datos de forma correcta 
datos_a = pd.read_csv('/content/drive/MyDrive/InmersionDatosALURA/Identificación (Capítulo A).csv', sep = ';',encoding='latin-1')
datos_a.head()
# Out:
#    DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0  3004346.00    11  11001      1           3.00         Santa Fe
# 1  3004347.00    11  11001      1          14.00     Los Mártires
# 2  3004348.00    11  11001      1           3.00         Santa Fe
# 3  3004349.00    11  11001      1           1.00          Usaquén
# 4  3004350.00    11  11001      1           1.00          Usaquén
#
#    COD_UPZ_GRUPO                        NOMBRE_UPZ_GRUPO  ESTRATO2021  \
# 0         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 1          37.00                            Santa Isabel     11001162
# 2         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 3         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
# 4         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
#
#                            NOMBRE_ESTRATO             FEX_C
# 0  SANTA FE: Las Nieves + Sagrado Corazón  13,2266692027239
# ...

# %%
# Consultadno tamaño del dataset
datos_a.shape
# Out:
# (106467, 11)

# %%
# Ubicando los datos correspondientes al municipio de Bogotá
#   Bogotá = 11001
datos_a = datos_a.loc[datos_a.MPIO == 11001]
datos_a.shape
# Out:
# (86504, 11)

# %%
# Trayendo nuevas bases de datos obtenidas del DANE
datos_b = pd.read_csv('/content/drive/MyDrive/InmersionDatosALURA/Datos de la vivenda y su entorno (Capítulo B).csv',sep=';',encoding='latin-1')
datos_c = pd.read_csv('/content/drive/MyDrive/InmersionDatosALURA/Condiciones habitacionales del hogar (Capítulo C).csv',sep=';',encoding='latin-1')
datos_e = pd.read_csv('/content/drive/MyDrive/InmersionDatosALURA/Composición del hogar y demografía (Capítulo E).csv',sep=';',encoding='latin-1')
datos_h = pd.read_csv('/content/drive/MyDrive/InmersionDatosALURA/Educación (Capitulo H).csv',sep=';',encoding='latin-1')
datos_l = pd.read_csv('/content/drive/MyDrive/InmersionDatosALURA/Percepción sobre las condiciones de vida y el desempeño institucional (Capítulo L).csv',sep=';',encoding='latin-1')
datos_k = pd.read_csv('/content/drive/MyDrive/InmersionDatosALURA/Fuerza de trabajo (Capítulo K).csv',sep=';',encoding='latin-1')
# Out:
# <ipython-input-70-b2a0a3025c56>:3: DtypeWarning: Columns (4,25,30,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_c = pd.read_csv('/content/drive/MyDrive/InmersionDatosALURA/Condiciones habitacionales del hogar (Capítulo C).csv',sep=';',encoding='latin-1')
# <ipython-input-70-b2a0a3025c56>:4: DtypeWarning: Columns (66) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_e = pd.read_csv('/content/drive/MyDrive/InmersionDatosALURA/Composición del hogar y demografía (Capítulo E).csv',sep=';',encoding='latin-1')
# <ipython-input-70-b2a0a3025c56>:5: DtypeWarning: Columns (26,81) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_h = pd.read_csv('/content/drive/MyDrive/InmersionDatosALURA/Educación (Capitulo H).csv',sep=';',encoding='latin-1')
# ...

# %%
# Juntando las tablas teniendo en cuenta el identificador DIRECTORIO haciendo un left join
datos_dane = pd.merge(datos_a,datos_b,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (86504, 73)

# %%
# Haciendo un merge con el merge anterior
datos_dane = pd.merge(datos_dane,datos_c,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (87061, 214)

# %%
# Haciendo un nuevo merge
datos_dane = pd.merge(datos_dane,datos_e,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# <ipython-input-73-f20844b1c512>:2: FutureWarning: Passing 'suffixes' which cause duplicate columns {'FEX_C_x'} in the result is deprecated and will raise a MergeError in a future version.
#   datos_dane = pd.merge(datos_dane,datos_e,on='DIRECTORIO', how='left')
# (238559, 281)

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 238559 entries, 0 to 238558
# Columns: 281 entries, DIRECTORIO to FEX_C_y
# dtypes: float64(140), int64(126), object(15)
# memory usage: 513.3+ MB

# %% [markdown]
# *Al estar haciendo demasiados merge, el consumo de memoria aumenta y podemos caer en la generación de BIG DATA*

# %% [markdown]
# **Desafío**
#
# 1. Dar un vistazo a la base de datos del DANE, entender estas variables conceptualmente para entender mejor el contexto de esta base.
#
# 2. Organizar tu notebook para que tu proyecto quede mejor presentado. (LISTO)

# %% [markdown]
# Entendiendo la base de datos...
#
# - Capítulo A: Contiene información sobre las variables de identificación de la encuesta: Departamento, municipio, clase, localidad (si es Bogotá), segmento, entre otros datos.
#
# - Capítulo B: Información relacionada con la calidad del entorno de la vivienda, así como vías de acceso e iluminación de estas. Características y condiciones habitacionales de la vivienda. Información acerca si la vivienda es afectada por problemas estructurales y de ubicación. Información acerca del riesgo de las viviendas ante problemas ambientales dada la ubicación cerca de focos de afectación como: fábricas, basureros, bares etc. Cobertura de los servicios públicos domiciliarios.
#
# - Capítulo C:  Este capítulo contiene información acerca de los hogares que tienen vivienda propia, hogares arrendatarios y los que habitan la vivienda en otra condición (usufructo, posesión sin título, ocupante de hecho). Información sobre el monto de los gastos en que incurre el hogar para tener el derecho de habitar la vivienda, como son los pagos por arriendo y la cuota de administración o celaduría. Información sobre las fuentes de financiación que usan los hogares para la compra de vivienda. Información sobre la calidad de la vivienda en términos de los espacios y las características de los servicios y equipamientos de los que dispone. Información con respecto a los subsidios para vivienda otorgados por el gobierno u otra institución. Información sobre los hogares que clasifican las basuras y los hogares que realizan prácticas para reducir el consumo de agua y energía.
#
# - Capítulo e: Información básica sobre el tamaño, distribución y dinámica demográfica de la población en Bogotá y los municipios seleccionados. Características socio-demográficas de la población residente en Bogotá y los municipios seleccionados. Personas que conforman el hogar y el núcleo familiar correspondiente al jefe/a del hogar. Información sobre migración de largo y corto plazo, así como entre áreas urbanas y rurales y entre barrios o veredas.
#
# - Capítulo h: Principales características educativas de la población de 5 años y más: alfabetismo, asistencia escolar, niveles alcanzados y años de estudio.Información acerca de las razones de no asistencia de la población en edad escolar.Información acerca del medio de transporte y el tiempo utilizado en el desplazamiento al establecimiento educativo. Información acerca de subsidios, becas y créditos educativos, así como las entidades que los otorgan. Gasto de los hogares en educación. Información acerca de la persona con quien permanecen los menores entre 5 y 17 años.
#
# - Capítulo k: Información sobre la actividad económica de la población de Bogotá y los municipios seleccionados de Cundinamarca. Información acerca de las personas dentro del hogar que devengan ingresos y si estos ingresos provienen de su vinculación al mercado laboral o de otras actividades o transferencias. Información sobre las condiciones de trabajo de los ocupados, como son el acceso a la seguridad social, horas trabajadas, ingresos, empleo secundario. De este capítulo se puede caracterizar las personas desocupadas e inactivas, determinando si perciben ingresos por otras fuentes como ayudas de familiares, amigos o instituciones. Información sobre el tiempo empleado en actividades no remuneradas, con enfoque de género. Información sobre teletrabajo y trabajo en casa en los últimos 12 meses y si el motivo de esta modalidad de trabajo fue la pandemia del COVID-19.
#
# - Capítulo l: Información sobre eventos destacados que afectan las condiciones de vida de los hogares y sobre la victimización de que han sido objeto sus miembros frente a agresiones criminales durante los últimos 12 meses. La información permite conocer la percepción sobre los cambios y estado actual en los equipamientos urbanos, en el medio ambiente, en algunos campos de desempeño institucional de la administración pública y en la igualdad de oportunidades de grupos poblacionales vulnerables. Información de los hogares beneficiarios de subsidios del gobierno nacional, departamental o municipal.

# %%
datos_a.head(3)
# Out:
#    DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0  3004346.00    11  11001      1           3.00         Santa Fe
# 1  3004347.00    11  11001      1          14.00     Los Mártires
# 2  3004348.00    11  11001      1           3.00         Santa Fe
#
#    COD_UPZ_GRUPO                        NOMBRE_UPZ_GRUPO  ESTRATO2021  \
# 0         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 1          37.00                            Santa Isabel     11001162
# 2         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
#
#                            NOMBRE_ESTRATO             FEX_C
# 0  SANTA FE: Las Nieves + Sagrado Corazón  13,2266692027239
# 1                            Santa Isabel  17,8555889419101
# 2  SANTA FE: Las Nieves + Sagrado Corazón  10,0286103658331

# %%
datos_b.head(3)
# Out:
#    DIRECTORIO  NVCBP1  NVCBP2  NVCBP3  NVCBP4  NVCBP5  NVCBP6  NVCBP7  \
# 0  3005117.00       4    1.00       1       1       1      12    1.00
# 1  3005118.00       2    1.00       1       2       1       5    2.00
# 2  3005119.00       1     NaN       1       2       1       1     NaN
#
#    NVCBP8A  NVCBP8B  ...  NVCBP15J  NVCBP15K  NVCBP15L  NVCBP15M  NVCBP16A1  \
# 0        2        2  ...         2         2         2         2          1
# 1        2        2  ...         2         2         2         2          1
# 2        2        2  ...         2         2         2         2          2
#
#    NVCBP16A2  NVCBP16A3  NVCBP16A4  NVCBP16             FEX_C
# 0          1          1          1        1  19,5771388808791
# 1          1          1          1        1  11,3314401226775
# 2          2          2          2        1  5,67151636864259
#
# [3 rows x 63 columns]

# %%
datos_c.head(3)
# Out:
#    DIRECTORIO  DIRECTORIO_HOG  SECUENCIA_P  NHCCP1 NHCCP2  NHCCP3  NHCCP4A  \
# 0  1165355.00        11653551            1       2  1e+06    1.00     1.00
# 1  1165356.00        11653561            1       3    NaN     NaN      NaN
# 2  1165357.00        11653571            1       1    NaN    1.00     1.00
#
#    NHCCP4B  NHCCP4C  NHCCP4D  ...  NHCCP46J NHCCP46K  NHCCP46L NHCCP46M  \
# 0      NaN      NaN      NaN  ...     30.00    15.00      5.00    60.00
# 1      NaN      NaN      NaN  ...     30.00    15.00      5.00    60.00
# 2      NaN      NaN      NaN  ...     30.00    14.00      5.00    15.00
#
#    NHCCP47A  NHCCP47A1  NHCCP47B  NHCCP47B1  NHCCP47C             FEX_C
# 0         2        NaN         2        NaN         2  47,6106272985279
# 1         2        NaN         2        NaN         2  51,0122773592785
# 2         2        NaN         2        NaN         2   45,950197007885
#
# [3 rows x 142 columns]

# %%
datos_e.head(3)
# Out:
#    DIRECTORIO  DIRECTORIO_HOG  DIRECTORIO_PER  SECUENCIA_P  ORDEN  NPCEP4  \
# 0   166238.00         1662381        16623811            1      1      70
# 1   166238.00         1662381        16623812            1      2      78
# 2   220102.00         2201021        22010211            1      1      45
#
#    NPCEP_5  NPCEP5  SEXO  NPCEP6  ...  NPCEP22A  NPCEP24  NPCEP24A  NPCEP25  \
# 0        3       2     2       1  ...       NaN        3       NaN     1.00
# 1        3       1     1       2  ...       NaN        3       NaN    99.00
# 2        3       1     1       1  ...      1.00        2       NaN    10.00
#
#    NPCEP25A  NPCEP27  NPCEP26  NPCEP29  NPCEP29A             FEX_C
# 0      2.00     1.00     1.00      NaN       NaN  1,69849246231156
# 1       NaN     1.00     1.00      NaN       NaN  1,69849246231156
# 2       NaN     1.00     1.00      NaN       NaN  6,74441212899351
#
# [3 rows x 68 columns]

# %%
datos_h.head(3)
# Out:
#    DIRECTORIO  DIRECTORIO_HOG  DIRECTORIO_PER  SECUENCIA_P  ORDEN  NPCHP1  \
# 0   166238.00         1662381        16623811            1      1       1
# 1   166238.00         1662381        16623812            1      2       2
# 2   220102.00         2201021        22010211            1      1       1
#
#    NPCHP2  NPCHP3  NPCHP4  NPCHP4A  ...  NPCHP35D  NPCHP35E  NPCHP35F  \
# 0       2     NaN    3.00     3.00  ...      2.00      2.00      2.00
# 1       2     NaN    1.00      NaN  ...      2.00      2.00      2.00
# 2       2     NaN    3.00     5.00  ...      2.00      2.00      2.00
#
#    NPCHP35I  NPCHP35J  NPCHP35K  NPCHP36  NPCHP36A  NPCHP37             FEX_C
# 0      2.00      2.00      2.00        2       NaN      NaN  1,69849246231156
# 1      2.00      2.00      2.00        2       NaN      NaN  1,69849246231156
# 2      2.00      2.00      2.00        2       NaN      NaN  6,74441212899351
#
# [3 rows x 136 columns]

# %%
datos_k.head(3)
# Out:
#    DIRECTORIO  DIRECTORIO_HOG  DIRECTORIO_PER  SECUENCIA_P  ORDEN  NPCKP1  \
# 0   166238.00         1662381        16623811            1      1       4
# 1   166238.00         1662381        16623812            1      2       4
# 2   220102.00         2201021        22010214            1      4       3
#
#    NPCKP2  NPCKP3  NPCKP4  NPCKP5  ...  DES  FL  FFL  PET_DEFA  OCU_DEFA  \
# 0    2.00    2.00    2.00    2.00  ...    0   0    1         1         0
# 1    2.00    2.00    2.00    2.00  ...    0   0    1         1         0
# 2    2.00    2.00    2.00    2.00  ...    0   0    0         1         0
#
#    DES_DEFA  INI_DEFA  PEA_DEFA  OINFORMAL             FEX_C
# 0         0         1         0        NaN  1,69849246231156
# 1         0         1         0        NaN  1,69849246231156
# 2         0         1         0        NaN  6,74441212899351
#
# [3 rows x 170 columns]

# %%
datos_l.head(3)
# Out:
#    DIRECTORIO  DIRECTORIO_HOG  SECUENCIA_P  NHCLP1  NHCLP2A  NHCLP2B  NHCLP2C  \
# 0  1165355.00        11653551            1       1        2        2        2
# 1  1165356.00        11653561            1       1        2        2        2
# 2  1165357.00        11653571            1       1        2        2        2
#
#    NHCLP2D  NHCLP2E  NHCLP2AA  ...  NHCLP31AA  NHCLP31AB  NHCLP31AC  \
# 0        2        2         2  ...        NaN        NaN        NaN
# 1        2        2         2  ...        NaN        NaN        NaN
# 2        2        2         2  ...        NaN        NaN        NaN
#
#    NHCLP31BA  NHCLP31BB  NHCLP31BC  NHCLP31CA  NHCLP31CB  NHCLP31CC  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
#
#               FEX_C
# 0  47,6106272985279
# 1  51,0122773592785
# 2   45,950197007885
#
# ...

# %% [markdown]
# **Atributos que relacionan a las tablas**
#
# - Todas: DIRECTORIO (dentificador numérico de vivienda)
